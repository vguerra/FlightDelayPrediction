# %%
import os
import pandas as pd

# %%
PATH_TO_LOG_DIR="/usr/local/ML/Master/Module1/DistributedData/TPs/flights/data/local-1597177753451_log"

# %%
log_file_path = os.path.join(PATH_TO_LOG_DIR, 'part-00000')
with open(log_file_path) as log:
    df = pd.read_csv(log, sep='\t')
    ax = df.plot()
    print(df.columns[0], df.values[-1][0])
    print(df.columns[1], df.values[-1][1])
    ax.title.set_text('Losses')
# Out:
# trainLogLoss 0.435271
# validationLogLoss 0.743583
